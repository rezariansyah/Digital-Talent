# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv('metro-bike-share-trip-data.csv', delimiter = ',', encoding = "utf-8")
df

cek1 = pd.DataFrame(df, columns = ['Trip ID','Duration','Start Time','End Time','Bike ID','Starting Station ID','Ending Station ID','Plan Duration','Trip Route Category','Passholder Type'
]).dropna()
cek1
# Out:
# C:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Trip ID  Duration           Start Time             End Time  Bike ID  \
# 0        1912818       180  2016-07-07T04:17:00  2016-07-07T04:20:00   6281.0
# 1        1919661      1980  2016-07-07T06:00:00  2016-07-07T06:33:00   6281.0
# 2        1933383       300  2016-07-07T10:32:00  2016-07-07T10:37:00   5861.0
# 3        1944197     10860  2016-07-07T10:37:00  2016-07-07T13:38:00   5861.0
# 4        1940317       420  2016-07-07T12:51:00  2016-07-07T12:58:00   6674.0
# 5        1944075       780  2016-07-07T12:51:00  2016-07-07T13:04:00   6717.0
# 6        1944073       600  2016-07-07T12:54:00  2016-07-07T13:04:00   5721.0
# 7        1944067       600  2016-07-07T12:59:00  2016-07-07T13:09:00   5957.0
# ...

# %%
cek=cek1.loc[(cek1['Trip Route Category'] =='One Way')]
cek
# Out:
#          Trip ID  Duration           Start Time             End Time  Bike ID  \
# 5        1944075       780  2016-07-07T12:51:00  2016-07-07T13:04:00   6717.0
# 6        1944073       600  2016-07-07T12:54:00  2016-07-07T13:04:00   5721.0
# 7        1944067       600  2016-07-07T12:59:00  2016-07-07T13:09:00   5957.0
# 9        1944063       960  2016-07-07T13:01:00  2016-07-07T13:17:00   6351.0
# 10       1944061       960  2016-07-07T13:02:00  2016-07-07T13:18:00   6200.0
# 11       1944059       720  2016-07-07T13:03:00  2016-07-07T13:15:00   6110.0
# 12       1944058       360  2016-07-07T13:03:00  2016-07-07T13:09:00   5856.0
# 14       1944057       660  2016-07-07T13:04:00  2016-07-07T13:15:00   6717.0
# 15       1944055       480  2016-07-07T13:04:00  2016-07-07T13:12:00   6332.0
# 16       1944052      2100  2016-07-07T13:06:00  2016-07-07T13:41:00   5965.0
# 17       1944050       600  2016-07-07T13:07:00  2016-07-07T13:17:00   6608.0
# ...

# %%
cek['Jumlah']=cek['Trip ID'].count()
cek.groupby(['Ending Station ID']).Jumlah.count().nlargest(5)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Ending Station ID
# 3005.0    5923
# 3031.0    5196
# 3014.0    5054
# 3042.0    4907
# 3069.0    4601
# Name: Jumlah, dtype: int64

# %%
df['Jumlah']=df['Trip ID'].count()
df.groupby(['Ending Station ID']).Jumlah.count().nlargest(5)
# Out:
# Ending Station ID
# 3005.0    6262
# 3031.0    5517
# 3014.0    5385
# 3042.0    5293
# 3069.0    5072
# Name: Jumlah, dtype: int64

# %%
cek.count()
# Out:
# Trip ID                118969
# Duration               118969
# Start Time             118969
# Bike ID                118969
# Starting Station ID    118969
# Ending Station ID      118969
# Plan Duration          118969
# Trip Route Category    118969
# Passholder Type        118969
# dtype: int64

# %%
cek.isnull().sum()
# Out:
# Trip ID                0
# Duration               0
# Start Time             0
# Bike ID                0
# Starting Station ID    0
# Ending Station ID      0
# Plan Duration          0
# Trip Route Category    0
# Passholder Type        0
# dtype: int64

# %%
(sudah.value_counts()).plot.line()
